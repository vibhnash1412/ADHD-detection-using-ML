# %% [markdown]
# unzip the file and load data in colab environment

# %%
import zipfile
import os

zip_path = "/content/ADHD.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
  zip_ref.extractall("/content/data")

# %% [markdown]
# declaring bands and defining functions needed

# %%
import numpy as np
from scipy.signal import welch, butter, filtfilt, iirnotch

bands = {
    "delta": (0.5, 4),
    "theta": (4, 8),
    "alpha": (8, 13),
    "beta":  (13, 30),
    "gamma": (30, 45)
}

def bandpass_filter(data, low, high, fs, order=4):
    nyq = 0.5 * fs
    low = low/nyq
    high = high/nyq
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, data)

def compute_psd(data, fs, band):
    fmin, fmax = bands[band]
    freqs, psd = welch(data, fs=fs, nperseg=fs*2)
    mask = (freqs >= fmin) & (freqs <= fmax)
    return np.mean(psd[mask])

def notch_filter(data, f0, fs, Q=30):
    nyq = 0.5 * fs
    w0 = f0/nyq
    b, a = iirnotch(w0, Q)
    return filtfilt(b, a, data)

# %% [markdown]
# Extrat psd data from mat files and make a csv for it

# %%
dataframe_list=[]

# %%
import os
import scipy.io as sio
import pandas as pd

data_dir = "/content/data/ADHD/ADHD"

fs = 256

for file_name in os.listdir(data_dir):
    if file_name.endswith(".mat"):
        file_path = os.path.join(data_dir, file_name)

        mat_data = sio.loadmat(file_path, squeeze_me=True)

        key = file_name.split(".")[0]
        eeg_data = mat_data[key]

        n_channels = eeg_data.shape[1]
        all_results = []

        for ch in range(n_channels):
            signal = eeg_data[:, ch]

            filtered_signal = bandpass_filter(signal, 0.5, 45, fs, order=4)
            filtered_signal = notch_filter(filtered_signal, 50, fs)

            for band in bands:
                psd_val = compute_psd(filtered_signal, fs, band)
                all_results.append([ch+1, band, psd_val])

        df = pd.DataFrame(all_results, columns=["Channel", "Band", "PSD"])
        df["ADHD"] = 0

        dataframe_list.append(df)

print(f"Processed {len(dataframe_list)} files into dataframe_list.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2573743496.py in <cell line: 0>()
#      14     return filtfilt(b, a, data)
#      15
# ---> 16 for file_name in os.listdir(data_dir):
#      17     if file_name.endswith(".mat"):
#      18         file_path = os.path.join(data_dir, file_name)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data/ADHD/Control'

# %%
import os
import scipy.io as sio
import pandas as pd

data_dir = "/content/data/ADHD/Control"

fs = 256

for file_name in os.listdir(data_dir):
    if file_name.endswith(".mat"):
        file_path = os.path.join(data_dir, file_name)

        mat_data = sio.loadmat(file_path, squeeze_me=True)

        key = file_name.split(".")[0]
        eeg_data = mat_data[key]

        n_channels = eeg_data.shape[1]
        all_results = []

        for ch in range(n_channels):
            signal = eeg_data[:, ch]

            filtered_signal = bandpass_filter(signal, 0.5, 45, fs, order=4)
            filtered_signal = notch_filter(filtered_signal, 50, fs)

            for band in bands:
                psd_val = compute_psd(filtered_signal, fs, band)
                all_results.append([ch+1, band, psd_val])

        df = pd.DataFrame(all_results, columns=["Channel", "Band", "PSD"])
        df["ADHD"] = 0

        # Append to list
        dataframe_list.append(df)

print(f"Processed {len(dataframe_list)} files into dataframe_list.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2573743496.py in <cell line: 0>()
#      14     return filtfilt(b, a, data)
#      15
# ---> 16 for file_name in os.listdir(data_dir):
#      17     if file_name.endswith(".mat"):
#      18         file_path = os.path.join(data_dir, file_name)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data/ADHD/Control'

# %%
print(dataframe_list)
# Out:
# [    Channel   Band          PSD  ADHD
# 0         1  delta  5380.886965     1
# 1         1  theta  2625.230609     1
# 2         1  alpha   792.356271     1
# 3         1   beta   223.754579     1
# 4         1  gamma    62.610601     1
# ..      ...    ...          ...   ...
# 90       19  delta  4483.348468     1
# 91       19  theta  1881.642610     1
# 92       19  alpha   745.944210     1
# 93       19   beta   244.068657     1
# 94       19  gamma    41.982108     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4221.374354     1
# 1         1  theta  2787.175677     1
# 2         1  alpha   734.487043     1
# 3         1   beta   151.424033     1
# 4         1  gamma    31.299449     1
# ..      ...    ...          ...   ...
# 90       19  delta  1373.861123     1
# 91       19  theta   906.200915     1
# 92       19  alpha   559.252000     1
# 93       19   beta   234.289061     1
# 94       19  gamma    47.089732     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  3083.811126     1
# 1         1  theta  1628.801800     1
# 2         1  alpha   817.147133     1
# 3         1   beta   334.681829     1
# 4         1  gamma    36.413846     1
# ..      ...    ...          ...   ...
# 90       19  delta  2620.210577     1
# 91       19  theta  1616.657436     1
# 92       19  alpha   606.975757     1
# 93       19   beta   258.149304     1
# 94       19  gamma    40.384011     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  10614.076587     1
# 1         1  theta   4239.898559     1
# 2         1  alpha   1182.705262     1
# 3         1   beta    477.912733     1
# 4         1  gamma     39.120483     1
# ..      ...    ...           ...   ...
# 90       19  delta   1181.292347     1
# 91       19  theta   3631.017566     1
# 92       19  alpha   1196.060796     1
# 93       19   beta   1181.933074     1
# 94       19  gamma     59.369128     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  6636.247511     1
# 1         1  theta  2757.950478     1
# 2         1  alpha   848.601456     1
# 3         1   beta   204.547854     1
# 4         1  gamma    50.990682     1
# ..      ...    ...          ...   ...
# 90       19  delta  1423.601401     1
# 91       19  theta  1076.733884     1
# 92       19  alpha   637.952769     1
# 93       19   beta   236.003596     1
# 94       19  gamma    34.841121     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  15780.839744     1
# 1         1  theta  20428.814836     1
# 2         1  alpha   5777.823358     1
# 3         1   beta    784.082710     1
# 4         1  gamma    144.150447     1
# ..      ...    ...           ...   ...
# 90       19  delta   8059.769427     1
# 91       19  theta   2503.348201     1
# 92       19  alpha    998.300521     1
# 93       19   beta    368.324845     1
# 94       19  gamma     86.998611     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  10640.084557     1
# 1         1  theta   3021.594465     1
# 2         1  alpha   1067.651814     1
# 3         1   beta    254.300700     1
# 4         1  gamma     63.887417     1
# ..      ...    ...           ...   ...
# 90       19  delta   1151.410285     1
# 91       19  theta   1027.687953     1
# 92       19  alpha    571.152154     1
# 93       19   beta    239.398441     1
# 94       19  gamma     45.621920     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4544.803689     1
# 1         1  theta  2139.575052     1
# 2         1  alpha   617.755414     1
# 3         1   beta   176.801642     1
# 4         1  gamma    53.045408     1
# ..      ...    ...          ...   ...
# 90       19  delta  2234.609910     1
# 91       19  theta  1467.983298     1
# 92       19  alpha   594.046263     1
# 93       19   beta   177.045274     1
# 94       19  gamma    21.264617     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5633.796212     1
# 1         1  theta  3174.259987     1
# 2         1  alpha  1196.932285     1
# 3         1   beta   271.751318     1
# 4         1  gamma    29.245628     1
# ..      ...    ...          ...   ...
# 90       19  delta  4176.227651     1
# 91       19  theta  1515.872469     1
# 92       19  alpha   593.156483     1
# 93       19   beta   217.916094     1
# 94       19  gamma    23.876849     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1130.017562     1
# 1         1  theta   827.938083     1
# 2         1  alpha   406.404317     1
# 3         1   beta   112.921796     1
# 4         1  gamma    38.625224     1
# ..      ...    ...          ...   ...
# 90       19  delta   840.448355     1
# 91       19  theta   875.871587     1
# 92       19  alpha   557.061477     1
# 93       19   beta   129.193895     1
# 94       19  gamma    28.624710     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  19128.434671     1
# 1         1  theta   6848.044785     1
# 2         1  alpha   2025.483332     1
# 3         1   beta    424.853210     1
# 4         1  gamma     88.417633     1
# ..      ...    ...           ...   ...
# 90       19  delta   1250.089381     1
# 91       19  theta    806.293980     1
# 92       19  alpha    690.631461     1
# 93       19   beta    316.002017     1
# 94       19  gamma     41.172531     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  7279.104581     1
# 1         1  theta  5173.581891     1
# 2         1  alpha   659.833594     1
# 3         1   beta   122.269271     1
# 4         1  gamma    22.846713     1
# ..      ...    ...          ...   ...
# 90       19  delta  1445.235908     1
# 91       19  theta   866.839227     1
# 92       19  alpha   488.770342     1
# 93       19   beta   188.795937     1
# 94       19  gamma    21.063419     1
#
# [95 rows x 4 columns],     Channel   Band         PSD  ADHD
# 0         1  delta  894.910662     1
# 1         1  theta  780.344480     1
# 2         1  alpha  371.294644     1
# 3         1   beta  139.053500     1
# 4         1  gamma   45.994117     1
# ..      ...    ...         ...   ...
# 90       19  delta  769.837856     1
# 91       19  theta  831.260156     1
# 92       19  alpha  495.713428     1
# 93       19   beta  186.407829     1
# 94       19  gamma   37.855623     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  7886.793532     1
# 1         1  theta  2666.365568     1
# 2         1  alpha   819.192981     1
# 3         1   beta   279.138204     1
# 4         1  gamma    96.236760     1
# ..      ...    ...          ...   ...
# 90       19  delta   981.017280     1
# 91       19  theta   876.071171     1
# 92       19  alpha   514.274608     1
# 93       19   beta   333.701991     1
# 94       19  gamma    42.039425     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  3892.375354     1
# 1         1  theta  3420.638887     1
# 2         1  alpha  1286.506417     1
# 3         1   beta   268.722322     1
# 4         1  gamma    31.636618     1
# ..      ...    ...          ...   ...
# 90       19  delta  2514.801466     1
# 91       19  theta  2019.874362     1
# 92       19  alpha  1162.071928     1
# 93       19   beta   361.882274     1
# 94       19  gamma    54.309281     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  14011.112415     1
# 1         1  theta   4352.446337     1
# 2         1  alpha    781.147056     1
# 3         1   beta    227.562163     1
# 4         1  gamma     61.408395     1
# ..      ...    ...           ...   ...
# 90       19  delta  11251.164862     1
# 91       19  theta   3495.375707     1
# 92       19  alpha    872.349200     1
# 93       19   beta    310.428158     1
# 94       19  gamma     64.623403     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2425.490376     1
# 1         1  theta  1496.574914     1
# 2         1  alpha   926.702742     1
# 3         1   beta   438.199510     1
# 4         1  gamma   122.835382     1
# ..      ...    ...          ...   ...
# 90       19  delta  2077.964922     1
# 91       19  theta  1562.287218     1
# 92       19  alpha   861.513240     1
# 93       19   beta   536.794250     1
# 94       19  gamma   142.434214     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5519.756192     1
# 1         1  theta  3652.377990     1
# 2         1  alpha   973.623468     1
# 3         1   beta   200.860756     1
# 4         1  gamma    52.343564     1
# ..      ...    ...          ...   ...
# 90       19  delta  1331.092625     1
# 91       19  theta   987.743248     1
# 92       19  alpha   470.045633     1
# 93       19   beta   169.147903     1
# 94       19  gamma    33.442285     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1687.548046     1
# 1         1  theta  1296.331943     1
# 2         1  alpha   506.515511     1
# 3         1   beta   149.463707     1
# 4         1  gamma    47.162284     1
# ..      ...    ...          ...   ...
# 90       19  delta   916.728570     1
# 91       19  theta   771.428134     1
# 92       19  alpha   471.585017     1
# 93       19   beta   329.596322     1
# 94       19  gamma    30.775076     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  18982.327907     1
# 1         1  theta   9460.700743     1
# 2         1  alpha   2931.262981     1
# 3         1   beta    373.219869     1
# 4         1  gamma     41.391614     1
# ..      ...    ...           ...   ...
# 90       19  delta  16161.420305     1
# 91       19  theta   4748.153706     1
# 92       19  alpha   1246.630930     1
# 93       19   beta    252.365751     1
# 94       19  gamma     48.968779     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  13709.766931     1
# 1         1  theta   7655.738275     1
# 2         1  alpha   1553.168114     1
# 3         1   beta    215.345404     1
# 4         1  gamma     31.685748     1
# ..      ...    ...           ...   ...
# 90       19  delta   1395.172771     1
# 91       19  theta    791.391227     1
# 92       19  alpha    381.081089     1
# 93       19   beta    184.929360     1
# 94       19  gamma     36.396373     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  8484.377622     1
# 1         1  theta  6240.339492     1
# 2         1  alpha  1473.088590     1
# 3         1   beta   222.965647     1
# 4         1  gamma    58.152246     1
# ..      ...    ...          ...   ...
# 90       19  delta   735.020986     1
# 91       19  theta   155.956332     1
# 92       19  alpha    20.645717     1
# 93       19   beta     3.179008     1
# 94       19  gamma     0.735003     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1579.528631     1
# 1         1  theta  1349.970388     1
# 2         1  alpha   530.801533     1
# 3         1   beta   216.920668     1
# 4         1  gamma    96.512657     1
# ..      ...    ...          ...   ...
# 90       19  delta  1082.516526     1
# 91       19  theta  1246.433992     1
# 92       19  alpha   538.844827     1
# 93       19   beta   272.276889     1
# 94       19  gamma    35.045049     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5342.747615     1
# 1         1  theta  5574.251350     1
# 2         1  alpha  1702.541629     1
# 3         1   beta   212.402810     1
# 4         1  gamma    32.855550     1
# ..      ...    ...          ...   ...
# 90       19  delta   884.041166     1
# 91       19  theta  1103.273474     1
# 92       19  alpha   812.007697     1
# 93       19   beta   163.282203     1
# 94       19  gamma    30.199543     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  6682.992776     1
# 1         1  theta  6202.151085     1
# 2         1  alpha  1769.726703     1
# 3         1   beta   311.592820     1
# 4         1  gamma    73.169700     1
# ..      ...    ...          ...   ...
# 90       19  delta  3650.682663     1
# 91       19  theta  1916.382519     1
# 92       19  alpha   629.470948     1
# 93       19   beta   229.633518     1
# 94       19  gamma    67.429654     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1961.933424     1
# 1         1  theta  1476.312731     1
# 2         1  alpha   447.897994     1
# 3         1   beta   144.017493     1
# 4         1  gamma    30.383076     1
# ..      ...    ...          ...   ...
# 90       19  delta   485.379796     1
# 91       19  theta   478.666354     1
# 92       19  alpha   323.100308     1
# 93       19   beta   196.504846     1
# 94       19  gamma    27.587523     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  3991.193893     1
# 1         1  theta  2446.418946     1
# 2         1  alpha  1040.840137     1
# 3         1   beta   304.500304     1
# 4         1  gamma    55.563351     1
# ..      ...    ...          ...   ...
# 90       19  delta  1601.364677     1
# 91       19  theta  1095.831114     1
# 92       19  alpha   441.964058     1
# 93       19   beta   276.958302     1
# 94       19  gamma    50.286469     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2583.028980     1
# 1         1  theta  1599.616697     1
# 2         1  alpha   643.879954     1
# 3         1   beta   223.853336     1
# 4         1  gamma    54.634571     1
# ..      ...    ...          ...   ...
# 90       19  delta  3821.412831     1
# 91       19  theta  1743.738008     1
# 92       19  alpha   740.031153     1
# 93       19   beta   577.211924     1
# 94       19  gamma    61.660671     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5199.126977     1
# 1         1  theta  2849.503353     1
# 2         1  alpha   626.249104     1
# 3         1   beta   239.135035     1
# 4         1  gamma    38.975652     1
# ..      ...    ...          ...   ...
# 90       19  delta   834.886915     1
# 91       19  theta   734.041126     1
# 92       19  alpha   436.113271     1
# 93       19   beta   244.296311     1
# 94       19  gamma    30.072958     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2269.134061     1
# 1         1  theta  1934.140307     1
# 2         1  alpha   793.463589     1
# 3         1   beta   209.446463     1
# 4         1  gamma    57.820099     1
# ..      ...    ...          ...   ...
# 90       19  delta   826.114469     1
# 91       19  theta   793.259638     1
# 92       19  alpha   474.008125     1
# 93       19   beta   194.557591     1
# 94       19  gamma    33.063128     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1217.301738     1
# 1         1  theta   992.125748     1
# 2         1  alpha   452.685117     1
# 3         1   beta   258.148606     1
# 4         1  gamma   142.439551     1
# ..      ...    ...          ...   ...
# 90       19  delta  1151.153956     1
# 91       19  theta   913.972619     1
# 92       19  alpha   550.380735     1
# 93       19   beta   249.359970     1
# 94       19  gamma    62.316959     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  31058.028321     1
# 1         1  theta  13244.635814     1
# 2         1  alpha   3474.854784     1
# 3         1   beta    510.592098     1
# 4         1  gamma     72.400494     1
# ..      ...    ...           ...   ...
# 90       19  delta  13326.612717     1
# 91       19  theta   4999.779645     1
# 92       19  alpha    987.838492     1
# 93       19   beta    238.446652     1
# 94       19  gamma     44.081832     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5534.688054     1
# 1         1  theta  2738.682924     1
# 2         1  alpha   912.446799     1
# 3         1   beta   266.582446     1
# 4         1  gamma    59.388561     1
# ..      ...    ...          ...   ...
# 90       19  delta  3169.605660     1
# 91       19  theta  1417.360439     1
# 92       19  alpha   811.453278     1
# 93       19   beta   283.768174     1
# 94       19  gamma    40.756417     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta   964.596021     1
# 1         1  theta  1323.576805     1
# 2         1  alpha   954.746794     1
# 3         1   beta   309.247260     1
# 4         1  gamma    52.275818     1
# ..      ...    ...          ...   ...
# 90       19  delta   816.704018     1
# 91       19  theta  1357.508496     1
# 92       19  alpha  1091.711396     1
# 93       19   beta   213.254708     1
# 94       19  gamma    52.533436     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1312.808803     1
# 1         1  theta  1111.164224     1
# 2         1  alpha   447.552472     1
# 3         1   beta   126.314055     1
# 4         1  gamma    25.954754     1
# ..      ...    ...          ...   ...
# 90       19  delta  1941.545448     1
# 91       19  theta  1210.069957     1
# 92       19  alpha   504.764741     1
# 93       19   beta   146.421266     1
# 94       19  gamma    24.069503     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1607.915247     1
# 1         1  theta  1693.090530     1
# 2         1  alpha   563.463947     1
# 3         1   beta   156.861824     1
# 4         1  gamma    39.033617     1
# ..      ...    ...          ...   ...
# 90       19  delta  1435.037151     1
# 91       19  theta  1162.059478     1
# 92       19  alpha   564.383379     1
# 93       19   beta   260.487232     1
# 94       19  gamma    46.963320     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  10151.303140     1
# 1         1  theta   3997.762367     1
# 2         1  alpha   1062.735946     1
# 3         1   beta    227.170407     1
# 4         1  gamma     36.411609     1
# ..      ...    ...           ...   ...
# 90       19  delta   5126.356014     1
# 91       19  theta   1953.031486     1
# 92       19  alpha    667.041731     1
# 93       19   beta    356.967818     1
# 94       19  gamma     58.289484     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1785.325687     1
# 1         1  theta  1499.038130     1
# 2         1  alpha   546.590775     1
# 3         1   beta   139.201884     1
# 4         1  gamma    34.155099     1
# ..      ...    ...          ...   ...
# 90       19  delta  2346.040893     1
# 91       19  theta  1404.949849     1
# 92       19  alpha   623.494240     1
# 93       19   beta   254.189529     1
# 94       19  gamma    43.300118     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1186.479858     1
# 1         1  theta  1102.158965     1
# 2         1  alpha   646.858177     1
# 3         1   beta   140.187020     1
# 4         1  gamma    39.901412     1
# ..      ...    ...          ...   ...
# 90       19  delta  1111.348357     1
# 91       19  theta  1122.186154     1
# 92       19  alpha   789.696894     1
# 93       19   beta   153.062265     1
# 94       19  gamma    36.016983     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  6805.750224     1
# 1         1  theta  6696.426272     1
# 2         1  alpha  2045.659815     1
# 3         1   beta   450.046724     1
# 4         1  gamma    57.820204     1
# ..      ...    ...          ...   ...
# 90       19  delta  1499.183841     1
# 91       19  theta  1519.141640     1
# 92       19  alpha   700.466028     1
# 93       19   beta   257.891619     1
# 94       19  gamma    58.186770     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5156.692660     1
# 1         1  theta  6039.502436     1
# 2         1  alpha  1700.928868     1
# 3         1   beta   304.028237     1
# 4         1  gamma   131.471934     1
# ..      ...    ...          ...   ...
# 90       19  delta  1818.784277     1
# 91       19  theta  1261.104000     1
# 92       19  alpha   880.249861     1
# 93       19   beta   285.839356     1
# 94       19  gamma    80.775019     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2065.667192     1
# 1         1  theta  1434.817652     1
# 2         1  alpha   703.819720     1
# 3         1   beta   274.451016     1
# 4         1  gamma    50.654371     1
# ..      ...    ...          ...   ...
# 90       19  delta   834.361865     1
# 91       19  theta   577.568445     1
# 92       19  alpha   333.108899     1
# 93       19   beta   203.439837     1
# 94       19  gamma    28.620830     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1925.646754     1
# 1         1  theta  1758.653519     1
# 2         1  alpha   587.983127     1
# 3         1   beta   204.829668     1
# 4         1  gamma    48.199958     1
# ..      ...    ...          ...   ...
# 90       19  delta  1069.398672     1
# 91       19  theta   817.112116     1
# 92       19  alpha   350.469858     1
# 93       19   beta   252.481885     1
# 94       19  gamma    42.837815     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5943.259083     1
# 1         1  theta  2811.973095     1
# 2         1  alpha   581.828686     1
# 3         1   beta   204.062746     1
# 4         1  gamma    47.264558     1
# ..      ...    ...          ...   ...
# 90       19  delta   620.975233     1
# 91       19  theta   569.948273     1
# 92       19  alpha   326.454020     1
# 93       19   beta   158.773007     1
# 94       19  gamma    23.128517     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  6859.880427     1
# 1         1  theta  2874.677258     1
# 2         1  alpha   686.633049     1
# 3         1   beta   142.720918     1
# 4         1  gamma    59.634220     1
# ..      ...    ...          ...   ...
# 90       19  delta  8026.373639     1
# 91       19  theta  3511.572238     1
# 92       19  alpha   741.208350     1
# 93       19   beta   159.621226     1
# 94       19  gamma    42.706601     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1386.734281     1
# 1         1  theta  1118.707628     1
# 2         1  alpha   402.270242     1
# 3         1   beta   130.942826     1
# 4         1  gamma    39.495867     1
# ..      ...    ...          ...   ...
# 90       19  delta  1313.471013     1
# 91       19  theta  1014.415634     1
# 92       19  alpha   462.386131     1
# 93       19   beta   169.145991     1
# 94       19  gamma    38.998868     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  7615.835940     1
# 1         1  theta  4482.297540     1
# 2         1  alpha  1309.078438     1
# 3         1   beta   202.764728     1
# 4         1  gamma    22.450400     1
# ..      ...    ...          ...   ...
# 90       19  delta  2732.243462     1
# 91       19  theta  1288.271437     1
# 92       19  alpha   502.972269     1
# 93       19   beta   323.392797     1
# 94       19  gamma    25.049567     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5493.263020     1
# 1         1  theta  4483.712995     1
# 2         1  alpha  1363.161065     1
# 3         1   beta   304.201308     1
# 4         1  gamma    67.153577     1
# ..      ...    ...          ...   ...
# 90       19  delta  1812.204020     1
# 91       19  theta  1396.441217     1
# 92       19  alpha   882.083612     1
# 93       19   beta   296.511343     1
# 94       19  gamma    34.958123     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1926.571941     1
# 1         1  theta  1347.916976     1
# 2         1  alpha   782.105027     1
# 3         1   beta   382.540714     1
# 4         1  gamma   215.769705     1
# ..      ...    ...          ...   ...
# 90       19  delta  1503.363900     1
# 91       19  theta  1274.768539     1
# 92       19  alpha   712.083711     1
# 93       19   beta   416.850251     1
# 94       19  gamma   147.441401     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1944.183837     1
# 1         1  theta  1492.394321     1
# 2         1  alpha   448.967838     1
# 3         1   beta   137.824885     1
# 4         1  gamma    36.890810     1
# ..      ...    ...          ...   ...
# 90       19  delta   874.380407     1
# 91       19  theta   753.265435     1
# 92       19  alpha   420.859558     1
# 93       19   beta   193.297261     1
# 94       19  gamma    43.532839     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5308.740314     1
# 1         1  theta  3613.583942     1
# 2         1  alpha  1076.984637     1
# 3         1   beta   234.511537     1
# 4         1  gamma    35.055586     1
# ..      ...    ...          ...   ...
# 90       19  delta  1384.128590     1
# 91       19  theta  1102.560369     1
# 92       19  alpha   803.067199     1
# 93       19   beta   264.244400     1
# 94       19  gamma    33.578834     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4618.101047     1
# 1         1  theta  4763.031735     1
# 2         1  alpha  1160.144924     1
# 3         1   beta   256.883139     1
# 4         1  gamma    76.256499     1
# ..      ...    ...          ...   ...
# 90       19  delta   905.596702     1
# 91       19  theta   856.628488     1
# 92       19  alpha   532.890010     1
# 93       19   beta   275.833044     1
# 94       19  gamma    49.957639     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  3386.111300     1
# 1         1  theta  2987.119521     1
# 2         1  alpha   848.947133     1
# 3         1   beta   252.907166     1
# 4         1  gamma    62.066257     1
# ..      ...    ...          ...   ...
# 90       19  delta  1265.507821     1
# 91       19  theta   914.835789     1
# 92       19  alpha   380.493132     1
# 93       19   beta   155.345518     1
# 94       19  gamma    36.199320     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  13954.064657     1
# 1         1  theta  11777.015229     1
# 2         1  alpha   2071.214285     1
# 3         1   beta    227.256139     1
# 4         1  gamma     24.524897     1
# ..      ...    ...           ...   ...
# 90       19  delta    974.692898     1
# 91       19  theta    683.240344     1
# 92       19  alpha    333.315168     1
# 93       19   beta    214.242454     1
# 94       19  gamma     28.673159     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4626.922403     1
# 1         1  theta  2759.555020     1
# 2         1  alpha   597.026532     1
# 3         1   beta   186.781060     1
# 4         1  gamma    53.963273     1
# ..      ...    ...          ...   ...
# 90       19  delta  2633.910349     1
# 91       19  theta  1608.218858     1
# 92       19  alpha   492.812305     1
# 93       19   beta   194.324820     1
# 94       19  gamma    42.706697     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1478.793634     1
# 1         1  theta   883.518874     1
# 2         1  alpha   314.013418     1
# 3         1   beta    87.205550     1
# 4         1  gamma    20.375255     1
# ..      ...    ...          ...   ...
# 90       19  delta   631.597809     1
# 91       19  theta   558.841551     1
# 92       19  alpha   381.614926     1
# 93       19   beta   104.059482     1
# 94       19  gamma    15.047023     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2866.149918     1
# 1         1  theta  1906.133829     1
# 2         1  alpha   586.816931     1
# 3         1   beta   155.434867     1
# 4         1  gamma    81.900676     1
# ..      ...    ...          ...   ...
# 90       19  delta  2279.598238     1
# 91       19  theta  2178.288899     1
# 92       19  alpha  1023.382904     1
# 93       19   beta   194.797910     1
# 94       19  gamma    30.462467     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2479.678097     1
# 1         1  theta  1672.460000     1
# 2         1  alpha   533.917754     1
# 3         1   beta   117.257534     1
# 4         1  gamma    36.003458     1
# ..      ...    ...          ...   ...
# 90       19  delta  1424.213082     1
# 91       19  theta   969.819890     1
# 92       19  alpha   487.116335     1
# 93       19   beta   180.791801     1
# 94       19  gamma    22.277125     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4241.517426     1
# 1         1  theta  3230.362146     1
# 2         1  alpha   911.255706     1
# 3         1   beta   268.409005     1
# 4         1  gamma   181.175148     1
# ..      ...    ...          ...   ...
# 90       19  delta  1119.455010     1
# 91       19  theta   774.860042     1
# 92       19  alpha   398.490865     1
# 93       19   beta   465.435626     1
# 94       19  gamma    47.082375     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  11055.166369     1
# 1         1  theta   3358.362343     1
# 2         1  alpha   1724.308488     1
# 3         1   beta    462.476716     1
# 4         1  gamma     76.315297     1
# ..      ...    ...           ...   ...
# 90       19  delta   6448.173081     1
# 91       19  theta   2077.055897     1
# 92       19  alpha   1440.435131     1
# 93       19   beta    462.407759     1
# 94       19  gamma     81.047544     1
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  13007.788012     1
# 1         1  theta  10986.647022     1
# 2         1  alpha   2730.213071     1
# 3         1   beta    350.404836     1
# 4         1  gamma     64.944008     1
# ..      ...    ...           ...   ...
# 90       19  delta   2520.962479     1
# 91       19  theta   1960.524655     1
# 92       19  alpha   1022.197882     1
# 93       19   beta    334.630061     1
# 94       19  gamma     66.439522     1
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  6711.092467     0
# 1         1  theta  3841.037935     0
# 2         1  alpha   911.817283     0
# 3         1   beta   183.415637     0
# 4         1  gamma    22.766149     0
# ..      ...    ...          ...   ...
# 90       19  delta  7190.888696     0
# 91       19  theta  3717.032375     0
# 92       19  alpha  1047.727854     0
# 93       19   beta   218.459383     0
# 94       19  gamma    27.272644     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  59039.134741     0
# 1         1  theta  20692.760905     0
# 2         1  alpha   2330.805502     0
# 3         1   beta    312.955270     0
# 4         1  gamma    134.786596     0
# ..      ...    ...           ...   ...
# 90       19  delta  57485.046410     0
# 91       19  theta  19493.473850     0
# 92       19  alpha   2102.399107     0
# 93       19   beta    442.088523     0
# 94       19  gamma    164.885649     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  3267.873093     0
# 1         1  theta  2107.617070     0
# 2         1  alpha   798.427808     0
# 3         1   beta   231.917314     0
# 4         1  gamma    98.352264     0
# ..      ...    ...          ...   ...
# 90       19  delta  2635.432745     0
# 91       19  theta  2056.853967     0
# 92       19  alpha   967.941597     0
# 93       19   beta   239.866293     0
# 94       19  gamma    51.632534     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  11500.424886     0
# 1         1  theta   5763.811023     0
# 2         1  alpha   2605.227254     0
# 3         1   beta    480.607921     0
# 4         1  gamma     57.111769     0
# ..      ...    ...           ...   ...
# 90       19  delta  11420.738854     0
# 91       19  theta   5318.569416     0
# 92       19  alpha   2336.271440     0
# 93       19   beta    508.405229     0
# 94       19  gamma     26.208983     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2075.725524     0
# 1         1  theta  1541.653134     0
# 2         1  alpha   506.834793     0
# 3         1   beta   252.439533     0
# 4         1  gamma    60.815342     0
# ..      ...    ...          ...   ...
# 90       19  delta  1903.062105     0
# 91       19  theta  1030.460505     0
# 92       19  alpha   567.500426     0
# 93       19   beta   386.951428     0
# 94       19  gamma    57.055968     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2424.641613     0
# 1         1  theta  1708.005393     0
# 2         1  alpha   682.757851     0
# 3         1   beta   219.931388     0
# 4         1  gamma    48.330287     0
# ..      ...    ...          ...   ...
# 90       19  delta  1520.235680     0
# 91       19  theta   902.551569     0
# 92       19  alpha   473.003224     0
# 93       19   beta   190.998028     0
# 94       19  gamma    41.538963     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  9038.060051     0
# 1         1  theta  4869.333759     0
# 2         1  alpha  2347.966346     0
# 3         1   beta   421.999681     0
# 4         1  gamma    85.580116     0
# ..      ...    ...          ...   ...
# 90       19  delta  1530.925417     0
# 91       19  theta  1313.446944     0
# 92       19  alpha   922.323948     0
# 93       19   beta   248.929794     0
# 94       19  gamma    43.786902     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  18042.528024     0
# 1         1  theta   5608.402937     0
# 2         1  alpha   1277.651418     0
# 3         1   beta    255.250463     0
# 4         1  gamma     96.496076     0
# ..      ...    ...           ...   ...
# 90       19  delta   1820.607525     0
# 91       19  theta   1330.541042     0
# 92       19  alpha    514.381910     0
# 93       19   beta    245.032961     0
# 94       19  gamma     40.495412     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5173.362472     0
# 1         1  theta  4194.540024     0
# 2         1  alpha   830.522873     0
# 3         1   beta   122.249909     0
# 4         1  gamma    32.778764     0
# ..      ...    ...          ...   ...
# 90       19  delta  5617.467062     0
# 91       19  theta  4111.760084     0
# 92       19  alpha   704.463855     0
# 93       19   beta   105.602960     0
# 94       19  gamma    16.489052     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4000.588250     0
# 1         1  theta  3316.748512     0
# 2         1  alpha   994.583505     0
# 3         1   beta   297.155283     0
# 4         1  gamma    37.588253     0
# ..      ...    ...          ...   ...
# 90       19  delta  3703.313053     0
# 91       19  theta  3191.967826     0
# 92       19  alpha  1259.552640     0
# 93       19   beta   386.026624     0
# 94       19  gamma    45.024369     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1047.077302     0
# 1         1  theta   958.769971     0
# 2         1  alpha   426.064866     0
# 3         1   beta   172.691447     0
# 4         1  gamma    39.894574     0
# ..      ...    ...          ...   ...
# 90       19  delta   823.204701     0
# 91       19  theta   689.822191     0
# 92       19  alpha   396.404083     0
# 93       19   beta   238.225014     0
# 94       19  gamma    37.126107     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4096.644242     0
# 1         1  theta  3387.394053     0
# 2         1  alpha  1274.519905     0
# 3         1   beta   330.934773     0
# 4         1  gamma    76.045984     0
# ..      ...    ...          ...   ...
# 90       19  delta  2175.105293     0
# 91       19  theta  1352.447197     0
# 92       19  alpha   791.788651     0
# 93       19   beta   272.416116     0
# 94       19  gamma    67.649607     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1211.678373     0
# 1         1  theta   789.505751     0
# 2         1  alpha   336.257344     0
# 3         1   beta   132.840366     0
# 4         1  gamma    68.256190     0
# ..      ...    ...          ...   ...
# 90       19  delta  1745.505706     0
# 91       19  theta   963.814911     0
# 92       19  alpha   512.850276     0
# 93       19   beta   237.220693     0
# 94       19  gamma    59.970886     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  17539.247294     0
# 1         1  theta   6089.035767     0
# 2         1  alpha   1134.394804     0
# 3         1   beta    212.000385     0
# 4         1  gamma     55.862592     0
# ..      ...    ...           ...   ...
# 90       19  delta   1236.624076     0
# 91       19  theta    929.843879     0
# 92       19  alpha    378.261935     0
# 93       19   beta    220.603876     0
# 94       19  gamma     79.338005     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1700.294033     0
# 1         1  theta  1412.062933     0
# 2         1  alpha   544.780926     0
# 3         1   beta   105.471101     0
# 4         1  gamma    20.839904     0
# ..      ...    ...          ...   ...
# 90       19  delta  3246.700696     0
# 91       19  theta  2146.636658     0
# 92       19  alpha   610.095936     0
# 93       19   beta   136.765821     0
# 94       19  gamma    15.222316     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4049.470725     0
# 1         1  theta  2853.809956     0
# 2         1  alpha  1168.194963     0
# 3         1   beta   178.027248     0
# 4         1  gamma    49.401450     0
# ..      ...    ...          ...   ...
# 90       19  delta  5091.539814     0
# 91       19  theta  2844.350487     0
# 92       19  alpha  1089.587233     0
# 93       19   beta   200.441942     0
# 94       19  gamma    20.201848     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  56074.252434     0
# 1         1  theta  11209.531434     0
# 2         1  alpha   3059.944777     0
# 3         1   beta    709.003046     0
# 4         1  gamma    131.993610     0
# ..      ...    ...           ...   ...
# 90       19  delta  24713.995661     0
# 91       19  theta  13475.426823     0
# 92       19  alpha   5426.397904     0
# 93       19   beta   1208.603007     0
# 94       19  gamma    153.353060     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  14784.608063     0
# 1         1  theta   3373.173139     0
# 2         1  alpha   1183.347797     0
# 3         1   beta    204.872544     0
# 4         1  gamma     37.744869     0
# ..      ...    ...           ...   ...
# 90       19  delta   3314.713898     0
# 91       19  theta   1359.839903     0
# 92       19  alpha    640.099217     0
# 93       19   beta    159.572336     0
# 94       19  gamma     28.403047     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  7379.890035     0
# 1         1  theta  1530.242560     0
# 2         1  alpha   454.290340     0
# 3         1   beta   233.767385     0
# 4         1  gamma    40.947071     0
# ..      ...    ...          ...   ...
# 90       19  delta  7451.707003     0
# 91       19  theta  1850.124777     0
# 92       19  alpha   656.388150     0
# 93       19   beta   262.927189     0
# 94       19  gamma    26.948346     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  34126.811299     0
# 1         1  theta  10993.081671     0
# 2         1  alpha   2228.075646     0
# 3         1   beta    289.927269     0
# 4         1  gamma     45.313412     0
# ..      ...    ...           ...   ...
# 90       19  delta   4938.207474     0
# 91       19  theta   2714.489712     0
# 92       19  alpha   1077.330558     0
# 93       19   beta    246.584289     0
# 94       19  gamma     35.156954     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4521.974597     0
# 1         1  theta  3220.555545     0
# 2         1  alpha   841.413493     0
# 3         1   beta   190.546003     0
# 4         1  gamma    68.470141     0
# ..      ...    ...          ...   ...
# 90       19  delta  1836.670287     0
# 91       19  theta  1520.987697     0
# 92       19  alpha   614.897780     0
# 93       19   beta   610.725215     0
# 94       19  gamma    76.857149     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta   950.574735     0
# 1         1  theta   453.251734     0
# 2         1  alpha   183.788028     0
# 3         1   beta    50.478654     0
# 4         1  gamma     8.014437     0
# ..      ...    ...          ...   ...
# 90       19  delta  1584.468593     0
# 91       19  theta   580.027348     0
# 92       19  alpha   183.948116     0
# 93       19   beta    62.097912     0
# 94       19  gamma     9.311796     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1390.392838     0
# 1         1  theta   989.969999     0
# 2         1  alpha   298.587106     0
# 3         1   beta   129.014049     0
# 4         1  gamma    32.947871     0
# ..      ...    ...          ...   ...
# 90       19  delta  2510.936867     0
# 91       19  theta  1031.812152     0
# 92       19  alpha   447.089862     0
# 93       19   beta   139.275314     0
# 94       19  gamma    14.338922     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  10025.180371     0
# 1         1  theta   8943.256316     0
# 2         1  alpha   2582.707035     0
# 3         1   beta    287.746840     0
# 4         1  gamma     33.430244     0
# ..      ...    ...           ...   ...
# 90       19  delta   1427.347786     0
# 91       19  theta    768.115045     0
# 92       19  alpha    392.394417     0
# 93       19   beta    147.852070     0
# 94       19  gamma     29.736740     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  7408.244304     0
# 1         1  theta  4343.410090     0
# 2         1  alpha  1131.085741     0
# 3         1   beta   235.257807     0
# 4         1  gamma    74.445607     0
# ..      ...    ...          ...   ...
# 90       19  delta  1259.406152     0
# 91       19  theta  1144.416764     0
# 92       19  alpha   527.480590     0
# 93       19   beta   114.926725     0
# 94       19  gamma    11.662563     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  12722.225621     0
# 1         1  theta   4942.954777     0
# 2         1  alpha   1013.861200     0
# 3         1   beta    202.102444     0
# 4         1  gamma     32.198596     0
# ..      ...    ...           ...   ...
# 90       19  delta  18318.988715     0
# 91       19  theta   5408.733523     0
# 92       19  alpha   1645.142243     0
# 93       19   beta    288.716836     0
# 94       19  gamma     50.570517     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  43990.601927     0
# 1         1  theta  15325.545054     0
# 2         1  alpha   3413.240062     0
# 3         1   beta    479.539685     0
# 4         1  gamma     69.380412     0
# ..      ...    ...           ...   ...
# 90       19  delta  41159.562412     0
# 91       19  theta   9923.603322     0
# 92       19  alpha   1850.901730     0
# 93       19   beta    235.998611     0
# 94       19  gamma     16.332403     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2929.509058     0
# 1         1  theta  3047.793100     0
# 2         1  alpha   754.499827     0
# 3         1   beta   132.150615     0
# 4         1  gamma    22.502820     0
# ..      ...    ...          ...   ...
# 90       19  delta   605.030392     0
# 91       19  theta   667.915116     0
# 92       19  alpha   310.649701     0
# 93       19   beta   243.176239     0
# 94       19  gamma    27.437369     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5424.981334     0
# 1         1  theta  1773.084100     0
# 2         1  alpha   371.915450     0
# 3         1   beta   104.186140     0
# 4         1  gamma    23.566641     0
# ..      ...    ...          ...   ...
# 90       19  delta  1637.524145     0
# 91       19  theta  1034.132772     0
# 92       19  alpha   376.899880     0
# 93       19   beta   105.312031     0
# 94       19  gamma     7.287560     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1559.573166     0
# 1         1  theta  1360.593139     0
# 2         1  alpha   391.794147     0
# 3         1   beta    99.741790     0
# 4         1  gamma    40.804367     0
# ..      ...    ...          ...   ...
# 90       19  delta   903.999773     0
# 91       19  theta   710.532774     0
# 92       19  alpha   473.970957     0
# 93       19   beta   110.302762     0
# 94       19  gamma    28.355129     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4409.318769     0
# 1         1  theta  1819.683795     0
# 2         1  alpha   420.517035     0
# 3         1   beta    91.313418     0
# 4         1  gamma    12.322201     0
# ..      ...    ...          ...   ...
# 90       19  delta  4389.733367     0
# 91       19  theta  1918.656010     0
# 92       19  alpha   497.200437     0
# 93       19   beta   120.638841     0
# 94       19  gamma    10.573327     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  36207.724286     0
# 1         1  theta  13176.401331     0
# 2         1  alpha   2691.194352     0
# 3         1   beta    500.224007     0
# 4         1  gamma     63.595684     0
# ..      ...    ...           ...   ...
# 90       19  delta  33315.471986     0
# 91       19  theta  11458.384829     0
# 92       19  alpha   2388.563472     0
# 93       19   beta    571.429912     0
# 94       19  gamma     72.250587     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5761.337128     0
# 1         1  theta  1559.482828     0
# 2         1  alpha   343.413074     0
# 3         1   beta    84.331190     0
# 4         1  gamma    13.312627     0
# ..      ...    ...          ...   ...
# 90       19  delta  5970.894630     0
# 91       19  theta  1526.238745     0
# 92       19  alpha   366.659223     0
# 93       19   beta   169.298217     0
# 94       19  gamma    16.772390     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2134.718007     0
# 1         1  theta  1280.723721     0
# 2         1  alpha   579.160768     0
# 3         1   beta   212.080346     0
# 4         1  gamma    47.472008     0
# ..      ...    ...          ...   ...
# 90       19  delta  1696.656144     0
# 91       19  theta  1232.277179     0
# 92       19  alpha   636.202411     0
# 93       19   beta   319.512658     0
# 94       19  gamma    37.927588     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2001.391074     0
# 1         1  theta  1710.683510     0
# 2         1  alpha   863.110890     0
# 3         1   beta   227.275957     0
# 4         1  gamma    40.368632     0
# ..      ...    ...          ...   ...
# 90       19  delta  1037.487451     0
# 91       19  theta  1005.282849     0
# 92       19  alpha   957.977851     0
# 93       19   beta   899.500644     0
# 94       19  gamma    41.218084     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4417.763778     0
# 1         1  theta  5247.591518     0
# 2         1  alpha  1788.888472     0
# 3         1   beta   342.130018     0
# 4         1  gamma    71.485220     0
# ..      ...    ...          ...   ...
# 90       19  delta  1755.231954     0
# 91       19  theta  2201.142237     0
# 92       19  alpha  1374.317601     0
# 93       19   beta   216.152187     0
# 94       19  gamma    34.558197     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  3026.417028     0
# 1         1  theta  2566.889036     0
# 2         1  alpha   968.054144     0
# 3         1   beta   197.925201     0
# 4         1  gamma    68.603876     0
# ..      ...    ...          ...   ...
# 90       19  delta  3151.802561     0
# 91       19  theta  1722.181030     0
# 92       19  alpha   430.183782     0
# 93       19   beta    94.854962     0
# 94       19  gamma    22.009300     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  7266.004801     0
# 1         1  theta  2138.565497     0
# 2         1  alpha   443.036014     0
# 3         1   beta    82.494445     0
# 4         1  gamma    15.769145     0
# ..      ...    ...          ...   ...
# 90       19  delta  9302.785891     0
# 91       19  theta  2724.812178     0
# 92       19  alpha   713.524910     0
# 93       19   beta    98.314039     0
# 94       19  gamma    16.779266     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4613.195742     0
# 1         1  theta  2767.798423     0
# 2         1  alpha   822.680936     0
# 3         1   beta   134.474529     0
# 4         1  gamma    58.837953     0
# ..      ...    ...          ...   ...
# 90       19  delta  4820.226565     0
# 91       19  theta  2919.932709     0
# 92       19  alpha   909.182702     0
# 93       19   beta   163.213682     0
# 94       19  gamma    26.655005     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4389.894456     0
# 1         1  theta  1909.540808     0
# 2         1  alpha   555.880341     0
# 3         1   beta   267.865484     0
# 4         1  gamma    28.717029     0
# ..      ...    ...          ...   ...
# 90       19  delta  2341.874059     0
# 91       19  theta  1365.274792     0
# 92       19  alpha   658.920973     0
# 93       19   beta   385.176410     0
# 94       19  gamma    40.598542     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1953.131808     0
# 1         1  theta  1487.304868     0
# 2         1  alpha  1126.703569     0
# 3         1   beta   278.394774     0
# 4         1  gamma    42.182517     0
# ..      ...    ...          ...   ...
# 90       19  delta  1515.558787     0
# 91       19  theta  1451.257990     0
# 92       19  alpha  1221.167822     0
# 93       19   beta   325.071503     0
# 94       19  gamma    41.608427     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  6216.852239     0
# 1         1  theta  1693.926757     0
# 2         1  alpha   421.976913     0
# 3         1   beta   139.631493     0
# 4         1  gamma    51.558946     0
# ..      ...    ...          ...   ...
# 90       19  delta  2077.496032     0
# 91       19  theta   864.952751     0
# 92       19  alpha   248.736935     0
# 93       19   beta   169.715911     0
# 94       19  gamma    35.481060     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2481.470205     0
# 1         1  theta  2059.174168     0
# 2         1  alpha   649.473158     0
# 3         1   beta   136.319151     0
# 4         1  gamma    29.415014     0
# ..      ...    ...          ...   ...
# 90       19  delta  1563.159044     0
# 91       19  theta  1219.943877     0
# 92       19  alpha   369.626814     0
# 93       19   beta   230.821821     0
# 94       19  gamma    32.185877     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  3116.734886     0
# 1         1  theta  1786.146385     0
# 2         1  alpha   533.372434     0
# 3         1   beta   122.248013     0
# 4         1  gamma    20.284765     0
# ..      ...    ...          ...   ...
# 90       19  delta  3938.621258     0
# 91       19  theta  1305.325942     0
# 92       19  alpha   534.812923     0
# 93       19   beta   113.363339     0
# 94       19  gamma    21.270579     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  13766.516292     0
# 1         1  theta   6662.470704     0
# 2         1  alpha   2130.548471     0
# 3         1   beta    403.442891     0
# 4         1  gamma     75.012962     0
# ..      ...    ...           ...   ...
# 90       19  delta   9316.854713     0
# 91       19  theta   3860.781780     0
# 92       19  alpha   1283.410578     0
# 93       19   beta    506.882840     0
# 94       19  gamma     83.730562     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  6354.571524     0
# 1         1  theta  4329.268631     0
# 2         1  alpha  1007.711329     0
# 3         1   beta   255.109938     0
# 4         1  gamma   213.080140     0
# ..      ...    ...          ...   ...
# 90       19  delta  3074.392118     0
# 91       19  theta  2232.634944     0
# 92       19  alpha   709.311971     0
# 93       19   beta   182.380811     0
# 94       19  gamma    48.174298     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  24716.607329     0
# 1         1  theta  18921.381584     0
# 2         1  alpha   3579.056950     0
# 3         1   beta    501.521307     0
# 4         1  gamma    153.122969     0
# ..      ...    ...           ...   ...
# 90       19  delta   1772.309339     0
# 91       19  theta   1263.823292     0
# 92       19  alpha    546.635802     0
# 93       19   beta    259.393006     0
# 94       19  gamma     30.690779     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  3565.395374     0
# 1         1  theta  1308.018616     0
# 2         1  alpha   805.734319     0
# 3         1   beta   167.336876     0
# 4         1  gamma    68.708684     0
# ..      ...    ...          ...   ...
# 90       19  delta  3641.053969     0
# 91       19  theta  1538.383619     0
# 92       19  alpha  1150.544059     0
# 93       19   beta   187.946991     0
# 94       19  gamma    25.904094     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  19762.633325     0
# 1         1  theta   8996.915148     0
# 2         1  alpha    417.624699     0
# 3         1   beta    113.911408     0
# 4         1  gamma     29.397690     0
# ..      ...    ...           ...   ...
# 90       19  delta  20660.859961     0
# 91       19  theta   9187.607546     0
# 92       19  alpha    324.397964     0
# 93       19   beta    108.715058     0
# 94       19  gamma     13.723637     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  2153.478232     0
# 1         1  theta  1574.640237     0
# 2         1  alpha   455.418165     0
# 3         1   beta    97.898428     0
# 4         1  gamma    48.222994     0
# ..      ...    ...          ...   ...
# 90       19  delta  2509.095406     0
# 91       19  theta  1278.704327     0
# 92       19  alpha   382.343386     0
# 93       19   beta   125.488816     0
# 94       19  gamma    23.660840     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  7728.650135     0
# 1         1  theta  3987.256656     0
# 2         1  alpha  1114.492776     0
# 3         1   beta   190.319106     0
# 4         1  gamma    24.109197     0
# ..      ...    ...          ...   ...
# 90       19  delta  3210.224986     0
# 91       19  theta  1403.415492     0
# 92       19  alpha   585.584352     0
# 93       19   beta   168.506114     0
# 94       19  gamma    29.821524     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1448.160078     0
# 1         1  theta  1163.204361     0
# 2         1  alpha   565.306338     0
# 3         1   beta   209.036678     0
# 4         1  gamma    30.592512     0
# ..      ...    ...          ...   ...
# 90       19  delta  1160.053840     0
# 91       19  theta   959.473283     0
# 92       19  alpha   715.875843     0
# 93       19   beta   230.950985     0
# 94       19  gamma    27.213260     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  10094.632509     0
# 1         1  theta  12645.957003     0
# 2         1  alpha   1772.771295     0
# 3         1   beta    334.415999     0
# 4         1  gamma     86.351354     0
# ..      ...    ...           ...   ...
# 90       19  delta  11751.056756     0
# 91       19  theta   8403.584767     0
# 92       19  alpha   1298.717756     0
# 93       19   beta    402.490150     0
# 94       19  gamma     71.738425     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5274.867454     0
# 1         1  theta  2831.615843     0
# 2         1  alpha  1080.944527     0
# 3         1   beta   312.878590     0
# 4         1  gamma   113.371634     0
# ..      ...    ...          ...   ...
# 90       19  delta  1291.464435     0
# 91       19  theta   744.840613     0
# 92       19  alpha   467.959056     0
# 93       19   beta   325.524232     0
# 94       19  gamma    58.687333     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  1221.712788     0
# 1         1  theta   582.696206     0
# 2         1  alpha   189.037788     0
# 3         1   beta   101.531410     0
# 4         1  gamma    59.141260     0
# ..      ...    ...          ...   ...
# 90       19  delta  1254.425837     0
# 91       19  theta   555.780558     0
# 92       19  alpha   178.425945     0
# 93       19   beta    95.302866     0
# 94       19  gamma    15.870608     0
#
# [95 rows x 4 columns],     Channel   Band           PSD  ADHD
# 0         1  delta  27572.087659     0
# 1         1  theta  10406.035146     0
# 2         1  alpha   3792.600069     0
# 3         1   beta   1249.838784     0
# 4         1  gamma    388.500163     0
# ..      ...    ...           ...   ...
# 90       19  delta  25407.129093     0
# 91       19  theta   9283.264428     0
# 92       19  alpha   3924.822582     0
# 93       19   beta   1636.601260     0
# 94       19  gamma    400.801876     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  5557.004455     0
# 1         1  theta  1025.228302     0
# 2         1  alpha   433.811649     0
# 3         1   beta   303.732393     0
# 4         1  gamma    66.941320     0
# ..      ...    ...          ...   ...
# 90       19  delta  1538.917131     0
# 91       19  theta   847.627328     0
# 92       19  alpha   298.777337     0
# 93       19   beta   444.427022     0
# 94       19  gamma    84.850161     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  3794.086645     0
# 1         1  theta  1289.153531     0
# 2         1  alpha   374.393023     0
# 3         1   beta   100.982687     0
# 4         1  gamma    49.640397     0
# ..      ...    ...          ...   ...
# 90       19  delta  2267.548869     0
# 91       19  theta  1448.229096     0
# 92       19  alpha   527.710778     0
# 93       19   beta   184.300466     0
# 94       19  gamma    40.679715     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  3086.246104     0
# 1         1  theta  1909.180176     0
# 2         1  alpha   930.648724     0
# 3         1   beta   227.167775     0
# 4         1  gamma    46.713752     0
# ..      ...    ...          ...   ...
# 90       19  delta  4733.510426     0
# 91       19  theta  3608.536980     0
# 92       19  alpha  1680.100210     0
# 93       19   beta   665.914609     0
# 94       19  gamma   138.415321     0
#
# [95 rows x 4 columns],     Channel   Band          PSD  ADHD
# 0         1  delta  4717.651998     0
# 1         1  theta  3235.882957     0
# 2         1  alpha  1152.124235     0
# 3         1   beta   345.436010     0
# 4         1  gamma    34.225018     0
# ..      ...    ...          ...   ...
# 90       19  delta  1847.533123     0
# 91       19  theta  1032.928422     0
# 92       19  alpha   419.923250     0
# 93       19   beta   260.291201     0
# 94       19  gamma    34.380239     0
#
# [95 rows x 4 columns]]

# %% [markdown]
# Change into a single table for easy training 121 X 96

# %%
import pandas as pd

def subject_to_features(df):
    pivot_df = df.pivot(index="Channel", columns="Band", values="PSD")

    feature_row = pivot_df.to_numpy().flatten()

    channel_names = [f"Ch{ch}" for ch in pivot_df.index]
    band_names = pivot_df.columns
    flattened_column_names = [f"{ch}_{band}" for ch in channel_names for band in band_names]

    feature_df = pd.DataFrame([feature_row], columns=flattened_column_names)

    feature_df["ADHD"] = df["ADHD"].iloc[0]

    return feature_df

# %%
feature_matrix = pd.concat([subject_to_features(df) for df in dataframe_list], ignore_index=True)
print(feature_matrix)
# Out:
#        Ch1_alpha     Ch1_beta     Ch1_delta   Ch1_gamma     Ch1_theta  \
# 0     792.356271   223.754579   5380.886965   62.610601   2625.230609
# 1     734.487043   151.424033   4221.374354   31.299449   2787.175677
# 2     817.147133   334.681829   3083.811126   36.413846   1628.801800
# 3    1182.705262   477.912733  10614.076587   39.120483   4239.898559
# 4     848.601456   204.547854   6636.247511   50.990682   2757.950478
# ..           ...          ...           ...         ...           ...
# 116  3792.600069  1249.838784  27572.087659  388.500163  10406.035146
# 117   433.811649   303.732393   5557.004455   66.941320   1025.228302
# 118   374.393023   100.982687   3794.086645   49.640397   1289.153531
# 119   930.648724   227.167775   3086.246104   46.713752   1909.180176
# 120  1152.124235   345.436010   4717.651998   34.225018   3235.882957
#
#        Ch2_alpha     Ch2_beta     Ch2_delta   Ch2_gamma    Ch2_theta  ...  \
# 0     652.834278   217.106029   8413.837029  201.460547  2612.073693  ...
# 1     658.315815   140.576983   3991.836886   31.589063  2691.724590  ...
# 2     608.425264   270.294178   1215.016440   52.790802   882.136552  ...
# 3    1709.321764   613.688834   8930.753567   46.526441  5070.530820  ...
# 4    1436.270987   299.008637  17060.307001   87.951620  5097.569803  ...
# ..           ...          ...           ...         ...          ...  ...
# 116  3686.470304  1483.608516  23105.677562  791.319680  9997.466079  ...
# 117   529.427958   360.399091   5987.747203   91.293403  1447.775835  ...
# 118   267.078585    91.098757   2395.801722   50.648259   866.149333  ...
# 119   861.531810   222.380378   2466.724102   59.210244  1990.525177  ...
# 120  1254.397466   233.453892   3902.410048   39.660112  3100.461482  ...
#
#        Ch18_beta    Ch18_delta  Ch18_gamma   Ch18_theta   Ch19_alpha  \
# 0     310.961196   6701.759880   45.643758  2179.918301   745.944210
# 1     256.323123   1432.430173   32.463662   822.708743   559.252000
# 2     274.750352    734.582884   50.803080   743.721705   606.975757
# 3     681.624444   1487.673182   56.230239  2787.698824  1196.060796
# 4     321.202195   4270.309512   47.264268  2675.581185   637.952769
# ..           ...           ...         ...          ...          ...
# 116  1904.109166  13534.661105  805.767866  9201.384458  3924.822582
# 117   279.418616   1254.659994   90.793240   780.698228   298.777337
# 118   223.530080   1339.563238   32.358267   788.433860   527.710778
# 119   308.198020   2156.132793   63.337567  1496.788854  1680.100210
# 120   146.677499   1326.780481   26.605926   932.869756   419.923250
#
#        Ch19_beta    Ch19_delta  Ch19_gamma   Ch19_theta  ADHD
# 0     244.068657   4483.348468   41.982108  1881.642610     1
# 1     234.289061   1373.861123   47.089732   906.200915     1
# 2     258.149304   2620.210577   40.384011  1616.657436     1
# 3    1181.933074   1181.292347   59.369128  3631.017566     1
# 4     236.003596   1423.601401   34.841121  1076.733884     1
# ..           ...           ...         ...          ...   ...
# 116  1636.601260  25407.129093  400.801876  9283.264428     0
# 117   444.427022   1538.917131   84.850161   847.627328     0
# 118   184.300466   2267.548869   40.679715  1448.229096     0
# 119   665.914609   4733.510426  138.415321  3608.536980     0
# 120   260.291201   1847.533123   34.380239  1032.928422     0
#
# [121 rows x 96 columns]

# %% [markdown]
# importing models and defining features(X) and traget(Y)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import accuracy_score

X = feature_matrix.drop(columns=["ADHD"])
y = feature_matrix["ADHD"]

# %% [markdown]
# Random forest classifier

# %%
rf_clf = RandomForestClassifier(n_estimators=200, random_state=42)
rf_scores = cross_val_score(rf_clf, X, y, cv=5, scoring="accuracy")
print("Random Forest Accuracy:", rf_scores.mean())
# Out:
# Random Forest Accuracy: 0.6463333333333334

# %% [markdown]
# Logistic regression classifier

# %%
log_reg = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", LogisticRegression(max_iter=500, class_weight="balanced"))
])
log_scores = cross_val_score(log_reg, X, y, cv=5, scoring="accuracy")
print("Logistic Regression Accuracy:", log_scores.mean())
# Out:
# Logistic Regression Accuracy: 0.4959999999999999

# %% [markdown]
# Support Vector Machine classifier

# %%
svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", SVC(kernel="rbf", class_weight="balanced"))
])
svm_scores = cross_val_score(svm_clf, X, y, cv=5, scoring="accuracy")
print("SVM Accuracy:", svm_scores.mean())
# Out:
# SVM Accuracy: 0.6456666666666668

# %% [markdown]
# 5 layer vanilla Feedforward Neural Network

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)
y_test = torch.tensor(y_test, dtype=torch.long)

class FFN(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, dropout=0.3):
        super(FFN, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(hidden_dim, 32),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(16, 16),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(16, 2)
        )

    def forward(self, x):
        return self.layers(x)


input_dim = X.shape[1]
model = FFN(input_dim)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

epochs = 100
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()

    if (epoch+1) % 10 == 0:
        model.eval()
        with torch.no_grad():
            preds = torch.argmax(model(X_test), dim=1)
            acc = accuracy_score(y_test.numpy(), preds.numpy())
        print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}, Test Acc: {acc:.4f}")

model.eval()
with torch.no_grad():
    y_pred = torch.argmax(model(X_test), dim=1).numpy()
    final_acc = accuracy_score(y_test.numpy(), y_pred)
    print("Final Test Accuracy:", final_acc)
# Out:
# Epoch 10/100, Loss: 0.6914, Test Acc: 0.4800
# Epoch 20/100, Loss: 0.6791, Test Acc: 0.4800
# Epoch 30/100, Loss: 0.6588, Test Acc: 0.4800
# Epoch 40/100, Loss: 0.6494, Test Acc: 0.4000
# Epoch 50/100, Loss: 0.6335, Test Acc: 0.5600
# Epoch 60/100, Loss: 0.5975, Test Acc: 0.5200
# Epoch 70/100, Loss: 0.5569, Test Acc: 0.4800
# Epoch 80/100, Loss: 0.5355, Test Acc: 0.5200
# Epoch 90/100, Loss: 0.4912, Test Acc: 0.6000
# Epoch 100/100, Loss: 0.3888, Test Acc: 0.5600
# Final Test Accuracy: 0.56

# %% [markdown]
# FFN with residual coefficients

# %%
class ResidualFFN(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout=0.3):
        super(ResidualFFN, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim//2)
        self.fc4 = nn.Linear(hidden_dim//2, hidden_dim//4)
        self.fc_out = nn.Linear(hidden_dim//4, 2)

        self.proj2 = nn.Linear(hidden_dim, hidden_dim)
        self.proj4 = nn.Linear(hidden_dim // 2, hidden_dim // 4)

        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out1 = self.relu(self.fc1(x))
        out1 = self.dropout(out1)

        out2 = self.relu(self.fc2(out1))
        out2 = self.dropout(out2)
        if out1.shape[-1] != out2.shape[-1]:
            out2 = out2 + self.proj2(out1)
        else:
            out2 = out2 + out1


        out3 = self.relu(self.fc3(out2))
        out3 = self.dropout(out3)

        out4 = self.relu(self.fc4(out3))
        out4 = self.dropout(out4)
        if out3.shape[-1] != out4.shape[-1]:
             out4 = out4 + self.proj4(out3)
        else:
            out4 = out4 + out3


        out = self.fc_out(out4)
        return out

input_dim = X.shape[1]
model = ResidualFFN(input_dim)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

epochs = 100
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()

    if (epoch+1) % 10 == 0:
        model.eval()
        with torch.no_grad():
            preds = torch.argmax(model(X_test), dim=1)
            acc = accuracy_score(y_test.numpy(), preds.numpy())
        print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}, Test Acc: {acc:.4f}")

model.eval()
with torch.no_grad():
    y_pred = torch.argmax(model(X_test), dim=1).numpy()
    final_acc = accuracy_score(y_test.numpy(), y_pred)
    print("Final Test Accuracy:", final_acc)
# Out:
# Epoch 10/100, Loss: 0.6298, Test Acc: 0.4000
# Epoch 20/100, Loss: 0.5579, Test Acc: 0.5600
# Epoch 30/100, Loss: 0.4312, Test Acc: 0.7200
# Epoch 40/100, Loss: 0.2756, Test Acc: 0.5200
# Epoch 50/100, Loss: 0.1541, Test Acc: 0.5600
# Epoch 60/100, Loss: 0.1094, Test Acc: 0.5200
# Epoch 70/100, Loss: 0.0513, Test Acc: 0.4400
# Epoch 80/100, Loss: 0.0244, Test Acc: 0.4800
# Epoch 90/100, Loss: 0.0381, Test Acc: 0.4800
# Epoch 100/100, Loss: 0.0099, Test Acc: 0.6800
# Final Test Accuracy: 0.68

# %% [markdown]
# CNN

# %%
X = feature_matrix.drop(columns=["ADHD"]).values
y = feature_matrix["ADHD"].values

X_reshaped = X.reshape(-1, 19, 5)

scaler = StandardScaler()
X_reshaped = scaler.fit_transform(X.reshape(-1, X.shape[1])).reshape(-1, 19, 5)

X_train, X_test, y_train, y_test = train_test_split(
    X_reshaped, y, test_size=0.2, stratify=y, random_state=42
)

X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
y_test = torch.tensor(y_test, dtype=torch.long)

class EEG_CNN(nn.Module):
    def __init__(self):
        super(EEG_CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=(3,3), padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=(3,3), padding=1)
        self.pool = nn.MaxPool2d((2,2))
        self.dropout = nn.Dropout(0.3)
        self.relu = nn.ReLU()

        self._to_linear = None
        self._get_conv_output_size(X_train)


        self.fc1 = nn.Linear(self._to_linear, 64)
        self.fc2 = nn.Linear(64, 2)


    def _get_conv_output_size(self, x):
        with torch.no_grad():
            x = self.pool(self.relu(self.conv2(self.relu(self.conv1(x)))))
            self._to_linear = x.view(x.size(0), -1).size(1)


    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.pool(self.relu(self.conv2(x)))
        x = self.dropout(x)
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

model = EEG_CNN()

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
epochs = 50

for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()

    if (epoch+1) % 10 == 0:
        model.eval()
        with torch.no_grad():
            preds = torch.argmax(model(X_test), dim=1)
            acc = accuracy_score(y_test.numpy(), preds.numpy())
        print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}, Test Acc: {acc:.4f}")

model.eval()
with torch.no_grad():
    y_pred = torch.argmax(model(X_test), dim=1).numpy()
    final_acc = accuracy_score(y_test.numpy(), y_pred)
    print("Final Test Accuracy:", final_acc)
# Out:
# Epoch 10/50, Loss: 0.6209, Test Acc: 0.3600
# Epoch 20/50, Loss: 0.5681, Test Acc: 0.5200
# Epoch 30/50, Loss: 0.4968, Test Acc: 0.7200
# Epoch 40/50, Loss: 0.3743, Test Acc: 0.6000
# Epoch 50/50, Loss: 0.3023, Test Acc: 0.5600
# Final Test Accuracy: 0.56
